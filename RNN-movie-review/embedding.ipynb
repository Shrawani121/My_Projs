# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent = ['the glass of water', 
        'the glass of milk',
        'the cup of tea',
        'I am a good boy',
        'I am a good developer',
        'understanding the words and their meaning is important for NLP',
        'your videosare good']

# %%
sent
# Out:
# ['the glass of water',
#  'the glass of milk',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understanding the words and their meaning is important for NLP',
#  'your videosare good']

# %%
## Define the vocabulary size
voc_size = 10000

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[805, 2572, 6704, 3461],
#  [805, 2572, 6704, 4098],
#  [805, 6703, 6704, 9296],
#  [9016, 4613, 4629, 4554, 5530],
#  [9016, 4613, 4629, 4554, 3961],
#  [1897, 805, 7174, 7587, 6674, 742, 5932, 7499, 8454, 3761],
#  [8269, 7126, 4554]]

# %%
## word  Embedding Representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
sent_length = 8
embedded_docs =pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0  805 2572 6704 3461]
#  [   0    0    0    0  805 2572 6704 4098]
#  [   0    0    0    0  805 6703 6704 9296]
#  [   0    0    0 9016 4613 4629 4554 5530]
#  [   0    0    0 9016 4613 4629 4554 3961]
#  [7174 7587 6674  742 5932 7499 8454 3761]
#  [   0    0    0    0    0 8269 7126 4554]]

# %%
## feature representaion
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# c:\Users\win10\miniconda3\envs\myenv\Lib\site-packages\keras\src\layers\core\embedding.py:123: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# array([[[-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.0380568 , -0.04230745,  0.01885972, -0.01912308,
#          -0.02191797,  0.03365448, -0.02399094,  0.01200525,
#          -0.04416453,  0.03102395],
#         [ 0.04840431,  0.03578096,  0.0014862 , -0.04413679,
#          -0.01612068,  0.02004871,  0.0490648 ,  0.03709903,
#           0.04258049, -0.03390344],
#         [-0.04957452,  0.02954808, -0.02253575,  0.02247519,
#           0.04486326,  0.0380774 ,  0.00849538,  0.00227476,
#          -0.00918945,  0.01154679],
#         [ 0.03829621, -0.04849469, -0.02477261,  0.01785814,
#          -0.01565397, -0.02963053,  0.02113957, -0.04307345,
#          -0.02915829, -0.04968851]],
#
#        [[-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.0380568 , -0.04230745,  0.01885972, -0.01912308,
#          -0.02191797,  0.03365448, -0.02399094,  0.01200525,
#          -0.04416453,  0.03102395],
#         [ 0.04840431,  0.03578096,  0.0014862 , -0.04413679,
#          -0.01612068,  0.02004871,  0.0490648 ,  0.03709903,
#           0.04258049, -0.03390344],
#         [-0.04957452,  0.02954808, -0.02253575,  0.02247519,
#           0.04486326,  0.0380774 ,  0.00849538,  0.00227476,
#          -0.00918945,  0.01154679],
#         [ 0.03323499, -0.01568004,  0.01910761, -0.04507959,
#           0.02737876,  0.04234692, -0.01540778, -0.00532191,
#           0.0462705 ,  0.03491661]],
#
#        [[-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.0380568 , -0.04230745,  0.01885972, -0.01912308,
#          -0.02191797,  0.03365448, -0.02399094,  0.01200525,
#          -0.04416453,  0.03102395],
#         [ 0.01736976,  0.01646206, -0.01898514,  0.0099359 ,
#           0.01938789,  0.03727658, -0.04398498,  0.00934505,
#          -0.02887817,  0.00718017],
#         [-0.04957452,  0.02954808, -0.02253575,  0.02247519,
#           0.04486326,  0.0380774 ,  0.00849538,  0.00227476,
#          -0.00918945,  0.01154679],
#         [ 0.04070816, -0.04258792, -0.03791722, -0.01407267,
#          -0.03072204,  0.04479071, -0.01532729, -0.04687594,
#           0.0440151 , -0.01566697]],
#
#        [[-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [ 0.01986429,  0.0411776 ,  0.03949125,  0.01725217,
#           0.00283663,  0.00372018,  0.01106502,  0.01500883,
#           0.04570714,  0.04761313],
#         [-0.02600303,  0.01082166, -0.04007887,  0.04277756,
#          -0.01884658,  0.02753093, -0.04867381,  0.00408735,
#          -0.04293336, -0.03138685],
#         [-0.03459059,  0.02732224,  0.00715525, -0.02182137,
#          -0.015977  ,  0.00385593,  0.04880401, -0.04923752,
#          -0.03624346,  0.00940371],
#         [-0.04754389, -0.00071482, -0.01480756,  0.04334345,
#          -0.01404524, -0.0098009 , -0.00509744,  0.00248127,
#          -0.04250226,  0.02393075],
#         [-0.04175616,  0.03641329,  0.00825201, -0.02349007,
#          -0.01328679, -0.00113285, -0.0181445 ,  0.04721921,
#           0.03848786,  0.01043851]],
#
#        [[-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [ 0.01986429,  0.0411776 ,  0.03949125,  0.01725217,
#           0.00283663,  0.00372018,  0.01106502,  0.01500883,
#           0.04570714,  0.04761313],
#         [-0.02600303,  0.01082166, -0.04007887,  0.04277756,
#          -0.01884658,  0.02753093, -0.04867381,  0.00408735,
#          -0.04293336, -0.03138685],
#         [-0.03459059,  0.02732224,  0.00715525, -0.02182137,
#          -0.015977  ,  0.00385593,  0.04880401, -0.04923752,
#          -0.03624346,  0.00940371],
#         [-0.04754389, -0.00071482, -0.01480756,  0.04334345,
#          -0.01404524, -0.0098009 , -0.00509744,  0.00248127,
#          -0.04250226,  0.02393075],
#         [-0.02201222, -0.04066819, -0.03041205,  0.03662982,
#           0.03418479,  0.01149778,  0.01132771,  0.00943562,
#          -0.0408658 , -0.04147941]],
#
#        [[ 0.0275128 ,  0.0365494 , -0.04602579, -0.02328438,
#           0.04099854,  0.03691573,  0.04506875, -0.0102443 ,
#           0.02088579, -0.0285112 ],
#         [ 0.01185999, -0.02382696, -0.04779683, -0.01164057,
#          -0.00580173, -0.0193239 , -0.02308524,  0.02091591,
#           0.0345414 ,  0.03112778],
#         [ 0.0378457 , -0.035797  , -0.00022877,  0.01464975,
#          -0.02689373,  0.04135871, -0.01221162, -0.02695376,
#          -0.00949294,  0.03431327],
#         [ 0.03240149, -0.0101481 , -0.03170456, -0.04607539,
#          -0.04867895, -0.02987919, -0.01795664, -0.00840653,
#           0.03862676,  0.02343408],
#         [ 0.02857235,  0.03518087, -0.00986964, -0.03237246,
#          -0.00633035,  0.02999851, -0.04133165,  0.03494943,
#          -0.03006477, -0.04560157],
#         [ 0.00424855, -0.03379046,  0.01455944,  0.02033836,
#          -0.02651843,  0.01236396, -0.00570518,  0.01115473,
#          -0.01613971,  0.01835049],
#         [-0.01661844,  0.0455163 , -0.00507103,  0.01104448,
#          -0.01221292, -0.04334377, -0.04923197,  0.03793125,
#           0.04167144, -0.03645835],
#         [ 0.0206998 , -0.01458855,  0.02917838, -0.01390046,
#          -0.01746652,  0.00177292, -0.016403  , -0.00034759,
#           0.03849698, -0.03189855]],
#
#        [[-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [ 0.04049737, -0.00023744,  0.01341388,  0.0415176 ,
#          -0.00439923,  0.01999385,  0.01363556, -0.04068701,
#          -0.04406263, -0.00586497],
#         [ 0.00945405,  0.04412809,  0.0350116 , -0.01190041,
#           0.00607665, -0.02928157, -0.02157056, -0.02038848,
#           0.00880662, -0.01567098],
#         [-0.04754389, -0.00071482, -0.01480756,  0.04334345,
#          -0.01404524, -0.0098009 , -0.00509744,  0.00248127,
#          -0.04250226,  0.02393075]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0,  805, 2572, 6704, 3461], dtype=int32)

# %%
model.predict(embedded_docs[:1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# array([[[-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.04409429,  0.01991973,  0.03470636, -0.00184022,
#          -0.03364359,  0.0492242 ,  0.04586879,  0.02906776,
#          -0.04731956, -0.04678394],
#         [-0.0380568 , -0.04230745,  0.01885972, -0.01912308,
#          -0.02191797,  0.03365448, -0.02399094,  0.01200525,
#          -0.04416453,  0.03102395],
#         [ 0.04840431,  0.03578096,  0.0014862 , -0.04413679,
#          -0.01612068,  0.02004871,  0.0490648 ,  0.03709903,
#           0.04258049, -0.03390344],
#         [-0.04957452,  0.02954808, -0.02253575,  0.02247519,
#           0.04486326,  0.0380774 ,  0.00849538,  0.00227476,
#          -0.00918945,  0.01154679],
#         [ 0.03829621, -0.04849469, -0.02477261,  0.01785814,
#          -0.01565397, -0.02963053,  0.02113957, -0.04307345,
#          -0.02915829, -0.04968851]]], dtype=float32)
